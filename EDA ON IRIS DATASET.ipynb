# %% [markdown]
# # EDA ON IRIS DATASET

# %% [markdown]
# IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# IMPORTING IRIS DATASET

# %%
data=pd.read_csv(r"\Users\USER\Desktop\victor\Iris.csv")
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# THE SHAPE OF THE DATASET

# %%
data.shape
# Out:
# (150, 6)

# %%
data.info
# Out:
# <bound method DataFrame.info of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ...

# %%
data.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %% [markdown]
# DATA PRE-PROCESSING : Finding out NaN values

# %%
data.isna().any()
# Out:
# Id               False
# SepalLengthCm    False
# SepalWidthCm     False
# PetalLengthCm    False
# PetalWidthCm     False
# Species          False
# dtype: bool

# %% [markdown]
# STATISTICAL DESCRIPTION OF THE DATA

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# How many species of iris flower are in the dataset?

# %%
data['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# Characteristics of the species

# %%
max_sepal_length=data['SepalLengthCm'].max()
max_sepal_length
# Out:
# 7.9

# %%
#Species with the longest sepal

# %%
max_sepal_length_species=data.loc[data['SepalLengthCm']==max_sepal_length]['Species'].iloc[0]
max_sepal_length_species
# Out:
# 'Iris-virginica'

# %%
#species with the shortest sepal

# %%
min_sepal_length_species=data.loc[data['SepalLengthCm']==data['SepalLengthCm'].min()]['Species'].iloc[0]

# %%
min_sepal_length_species
# Out:
# 'Iris-setosa'

# %%
#species with the lowest sepal  width

# %%
min_SepalWidthCm_species=data.loc[data['SepalWidthCm']==data['SepalWidthCm'].min()]['Species'].iloc[0]

# %%
min_SepalWidthCm_species
# Out:
# 'Iris-versicolor'

# %%
#  specie with highest sepal widh

# %%
max_SepalWidthCm_species=data.loc[data['SepalWidthCm']==data['SepalWidthCm'].max()]['Species'].iloc[0]

# %%
max_SepalWidthCm_species
# Out:
# 'Iris-setosa'

# %%
#specie with the highest petallength

# %%
max_PetalLengthCm_species=data.loc[data['PetalLengthCm']==data['PetalLengthCm'].max()]['Species'].iloc[0]

# %%
max_PetalLengthCm_species
# Out:
# 'Iris-virginica'

# %%
#specie with the lowest petallength

# %%
min_PetalLengthCm_species=data.loc[data['PetalLengthCm']==data['PetalLengthCm'].min()]['Species'].iloc[0]
min_PetalLengthCm_species
# Out:
# 'Iris-setosa'

# %%
#specie with the lowest petal width

# %%
min_PetalWidthCm_species=data.loc[data['PetalWidthCm']==data['PetalWidthCm'].min()]['Species'].iloc[0]
min_PetalWidthCm_species
# Out:
# 'Iris-setosa'

# %%
#specie  with the highest petal width

# %%
max_PetalWidthCm_species=data.loc[data['PetalWidthCm']==data['PetalWidthCm'].max()]['Species'].iloc[0]
max_PetalWidthCm_species
# Out:
# 'Iris-virginica'

# %% [markdown]
# which specie has more record?

# %%
fig_dims=(20,10)
fig, ax=plt.subplots(figsize=fig_dims)
sns.countplot(x='Species',ax=ax,data=data)
plt.show()

# %%
# thay have equal records as show above

# %% [markdown]
# PLOTTING SEPAL LENGTH AND PETAL LENGTH

# %%
sns.scatterplot(x='SepalLengthCm',y='PetalLengthCm',data=data,hue='Species')
# Adding hue on species to discern better
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
sns.scatterplot(x='SepalLengthCm',y='PetalLengthCm',data=data,hue='PetalLengthCm')
# Adding hue on petal lenth  to diffrentiate
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
sns.scatterplot(x='SepalWidthCm',y='PetalWidthCm',data=data,hue='Species')
# Adding hue on species  to diffrentiate
# Out:
# <AxesSubplot:xlabel='SepalWidthCm', ylabel='PetalWidthCm'>
